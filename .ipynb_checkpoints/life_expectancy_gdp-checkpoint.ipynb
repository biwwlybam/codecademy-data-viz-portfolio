# %% [markdown]
# First I'll import `pandas` so that I can read the data in our csv file, `numpy` to manipulate the data, and `matplotlib` and `seaborn` to create data visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
life_ex = pd.read_csv('all_data.csv')

# %%
life_ex.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %% [markdown]
# In order to summarize the mean life expectancy and GDP for each country in our dataset, I'll use the `groupby()` and `mean()` functions together. To make the data easier to read, I'll also use the `sort_values()` function to list data in descending order of mean life expectancy. This has the added bonus of letting me know all the unique countries in our dataset.

# %%
life_ex.groupby('Country').mean().sort_values(by=['Life expectancy at birth (years)'], ascending=False)
# Out:
#                             Year  Life expectancy at birth (years)  \
# Country
# Germany                   2007.5                          79.65625
# Chile                     2007.5                          78.94375
# United States of America  2007.5                          78.06250
# Mexico                    2007.5                          75.71875
# China                     2007.5                          74.26250
# Zimbabwe                  2007.5                          50.09375
#
#                                    GDP
# Country
# Germany                   3.094776e+12
# Chile                     1.697888e+11
# United States of America  1.407500e+13
# Mexico                    9.766506e+11
# China                     4.957714e+12
# Zimbabwe                  9.062580e+09

# %% [markdown]
# We can see that Germany has the highest life expectancy, but not the highest GDP. This seems like two metrics that would be interesting to plot against each other.
#
# We can also see that Zimbabwe has the lowest life expectancy by a large amount, effectively an outlier in this data. This also makes me curious how many data points we have for each country. Below I'll use the `value_counts()` method on the `Country` column to check this.

# %%
life_ex['Country'].value_counts()
# Out:
# Chile                       16
# China                       16
# Germany                     16
# Mexico                      16
# United States of America    16
# Zimbabwe                    16
# Name: Country, dtype: int64

# %% [markdown]
# Nice to see that we have an equal number of data points from each country. I would also like to quickly check if there are any missing data points. The quickest way I can think of is using `isnull()` and `value_counts()` together. If there are any `True` values, we can investigate those further.

# %%
life_ex.isnull().value_counts()
# Out:
# Country  Year   Life expectancy at birth (years)  GDP
# False    False  False                             False    96
# dtype: int64

# %% [markdown]
# An even number of values for each country with no missing data points... this data is looking pretty clean so far.
#
# It appears from the `head()` and mean years that data is equally spread across years. It would be nice to confirm this and get the range at the same time.

# %%
life_ex['Year'].value_counts()
# Out:
# 2000    6
# 2001    6
# 2002    6
# 2003    6
# 2004    6
# 2005    6
# 2006    6
# 2007    6
# 2008    6
# 2009    6
# 2010    6
# 2011    6
# 2012    6
# 2013    6
# 2014    6
# 2015    6
# Name: Year, dtype: int64

# %% [markdown]
# ## Life expectancy from 2000 to 2015 by country

# %% [markdown]
# I'd like to see how life expectancies have changed over the 16 years we have data for. First I'll make an array containing the years for the x-axis, and then create arrays of life expectancy for each country and plot them all together for comparison.

# %%
years = np.arange(2000,2016)
life_ex_germany = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'Germany']
life_ex_chile = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'Chile']
life_ex_usa = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'United States of America']
life_ex_mexico = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'Mexico']
life_ex_china = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'China']
life_ex_zimbabwe = life_ex['Life expectancy at birth (years)'].loc[life_ex['Country'] == 'Zimbabwe']

plt.plot(years, life_ex_germany, label='Germany')
plt.plot(years, life_ex_chile, label='Chile')
plt.plot(years, life_ex_usa, label='USA')
plt.plot(years, life_ex_mexico, label='Mexico')
plt.plot(years, life_ex_china, label='China')
plt.plot(years, life_ex_zimbabwe, label='Zimbabwe')
plt.legend()
plt.title('Life Expectancy from 2000-2016')
plt.xlabel('Year')
plt.ylabel('Life expectancy in years')
plt.show()
plt.clf()

# %% [markdown]
# We're able to see that all of the countries we have data for increased their life expectancy between 2000 and 2016. Chile and Mexico had some periods of stagnant or falling life expectancy. Zimbabwe experienced a notable decrease from 2000 to 2004, but then an even more notable increase up to 2016, the last year we have data for.

# %% [markdown]
# ## GDP from 2000 to 2015 by country

# %% [markdown]
# Let's do the same thing for GDP and see if we can find a similar trend.

# %%
gdp_germany = life_ex['GDP'].loc[life_ex['Country'] == 'Germany']
gdp_chile = life_ex['GDP'].loc[life_ex['Country'] == 'Chile']
gdp_usa = life_ex['GDP'].loc[life_ex['Country'] == 'United States of America']
gdp_mexico = life_ex['GDP'].loc[life_ex['Country'] == 'Mexico']
gdp_china = life_ex['GDP'].loc[life_ex['Country'] == 'China']
gdp_zimbabwe = life_ex['GDP'].loc[life_ex['Country'] == 'Zimbabwe']

plt.figure(figsize=(10,10))
plt.plot(years, gdp_germany, label='Germany')
plt.plot(years, gdp_chile, label='Chile')
plt.plot(years, gdp_usa, label='USA')
plt.plot(years, gdp_mexico, label='Mexico')
plt.plot(years, gdp_china, label='China')
plt.plot(years, gdp_zimbabwe, label='Zimbabwe')
plt.legend()
plt.title('GDP from 2000-2016')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
plt.clf()

# %% [markdown]
# Obviously the USA and China have had strong GDP growth over this time period, to the extent that it's hard to gain any information from the other countries in this graph. Let's ignore the USA and China and see what we can see.

# %%
index_names = life_ex[ life_ex['Country'] == 'United State of America' ].index
life_ex_new = life_ex.drop(index_names)

index_names = life_ex_new[ life_ex_new['Country'] == 'China' ].index
life_ex_newer = life_ex_new.drop(index_names)

gdp_germany = life_ex_newer['GDP'].loc[life_ex['Country'] == 'Germany']
gdp_chile = life_ex_newer['GDP'].loc[life_ex['Country'] == 'Chile']
gdp_mexico = life_ex_newer['GDP'].loc[life_ex['Country'] == 'Mexico']
gdp_zimbabwe = life_ex_newer['GDP'].loc[life_ex['Country'] == 'Zimbabwe']

plt.figure(figsize=(10,10))
plt.plot(years, gdp_germany, label='Germany')
plt.plot(years, gdp_chile, label='Chile')
plt.plot(years, gdp_mexico, label='Mexico')
plt.plot(years, gdp_zimbabwe, label='Zimbabwe')
plt.legend()
plt.title('GDP from 2000-2016')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
plt.clf()

# %% [markdown]
# We can see that Germany, Chile, and Mexico all appear to have experienced positive GDP growth over this time period, though it's still unclear at this scale if Zimbabwe did. I'll go ahead and compare GDP in 2016 and GDP in 2000 for Zimbabwe.

# %%
zimbabwe_gdp_2015 = life_ex.iloc[95:96]['GDP'][95]
zimbabwe_gdp_2000 = life_ex.iloc[80:81]['GDP'][80]

zimbabwe_gdp_2015 - zimbabwe_gdp_2000
# Out:
# 9614710207.0

# %% [markdown]
# And so while not on the scale of the other countries that we have data for, we can see that Zimbabwe's GDP did rise between the years 2000 to 2015.

# %% [markdown]
# ## Life expectancy vs. GDP

# %% [markdown]
# I'll be exploring if there's any relationship between life expectancy and GDP, starting off with some scatterplots. First I'll pull the GDP data for each country and combine that with the life expectancies that we already have.

# %%
gdp_germany = life_ex['GDP'].loc[life_ex['Country'] == 'Germany']
gdp_chile = life_ex['GDP'].loc[life_ex['Country'] == 'Chile']
gdp_usa = life_ex['GDP'].loc[life_ex['Country'] == 'United States of America']
gdp_mexico = life_ex['GDP'].loc[life_ex['Country'] == 'Mexico']
gdp_china = life_ex['GDP'].loc[life_ex['Country'] == 'China']
gdp_zimbabwe = life_ex['GDP'].loc[life_ex['Country'] == 'Zimbabwe']

# %% [markdown]
# Then I will get a best fit line for each scatterplot using `np.polyfit()`.

# %%
theta_germany = np.polyfit(gdp_germany, life_ex_germany, 1)
y_line_germany = theta_germany[1] + theta_germany[0] * gdp_germany

theta_chile = np.polyfit(gdp_chile, life_ex_chile, 1)
y_line_chile = theta_chile[1] + theta_chile[0] * gdp_chile

theta_usa = np.polyfit(gdp_usa, life_ex_usa, 1)
y_line_usa = theta_usa[1] + theta_usa[0] * gdp_usa

theta_mexico = np.polyfit(gdp_mexico, life_ex_mexico, 1)
y_line_mexico = theta_mexico[1] + theta_mexico[0] * gdp_mexico

theta_china = np.polyfit(gdp_china, life_ex_china, 1)
y_line_china = theta_china[1] + theta_china[0] * gdp_china

theta_zimbabwe = np.polyfit(gdp_zimbabwe, life_ex_zimbabwe, 1)
y_line_zimbabwe = theta_zimbabwe[1] + theta_zimbabwe[0] * gdp_zimbabwe

# %%
plt.subplot(2,3,1)
plt.scatter(gdp_germany, life_ex_germany)
plt.plot(gdp_germany, y_line_germany, color='r')
plt.xlabel('Germany')

plt.subplot(2,3,2)
plt.scatter(gdp_chile, life_ex_chile)
plt.plot(gdp_chile, y_line_chile, color = 'r')
plt.title('GDP vs Life Expectancy')
plt.xlabel('Chile')

plt.subplot(2,3,3)
plt.scatter(gdp_usa, life_ex_usa)
plt.plot(gdp_usa, y_line_usa, color = 'r')
plt.xlabel('USA')

plt.subplot(2,3,4)
plt.scatter(gdp_mexico, life_ex_mexico)
plt.plot(gdp_mexico, y_line_mexico, color = 'r')
plt.xlabel('Mexico')

plt.subplot(2,3,5)
plt.scatter(gdp_china, life_ex_china)
plt.plot(gdp_china, y_line_china, color = 'r')
plt.xlabel('China')

plt.subplot(2,3,6)
plt.scatter(gdp_zimbabwe, life_ex_zimbabwe)
plt.plot(gdp_zimbabwe, y_line_zimbabwe, color = 'r')
plt.xlabel('Zimbabwe')

# space out plots for ease or reading and labels
plt.subplots_adjust(left=-0.5, bottom=-0.5, wspace=0.4, hspace=0.3)

plt.show()
plt.clf()

# %% [markdown]
# There is a positive association between GDP and life expectancy, however when we look at China and Zimbabwe we can see there must be more to the story that we may not have data for because the trend was not always as straightforward as the other countries we plotted.
#
# I realize we could have gotten this same information by just calculating the slope for each scatterplot, but this was more fun for this project. Since there is a clear and similar positive association for all countries, lets plot them all together so we can have a broad prediction of how GDP is associated with life expectancy.

# %%
plt.scatter(life_ex['GDP'], life_ex['Life expectancy at birth (years)'])

plt.show()

# %% [markdown]
# I think the data for Zimbabwe is making this graph challenging to read, as we could see it was effectively an outlier for our data from our previous exploratory analysis. Let's try dropping it from the data.

# %%
index_names = life_ex[ life_ex['Country'] == 'Zimbabwe' ].index
life_ex.drop(index_names, inplace=True)

plt.scatter(life_ex['GDP'], life_ex['Life expectancy at birth (years)'])
plt.title('GDP vs Life Expectancy')
plt.xlabel('GDP')
plt.ylabel('Life expectancy (years)')

plt.show()

# %% [markdown]
# Once again we can see that there's obviously more going on that effects life expectancy and GDP than just their effect on each other. I'd say it's hard to really draw serious conclusions from this data, considering low GDP countries are able to have very high life expectancies, although it appears that having a high GDP can strongly predict that you'll at least not have a "low" life expectancy.

# %% [markdown]
# One thing we were able to see though was that GDP and life expectancy both rose between the years 2000 to 2015 for all the countries that we have data for. There may not always be a comparable effect, but there seems to be at least some correlation and likely could be elucidated by other data that we don't have access to.
